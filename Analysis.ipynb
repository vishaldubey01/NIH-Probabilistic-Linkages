# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 500)

# %%
df_withencoding = pd.read_csv('dataset_noisy_with_encodings_renamed.csv')
df_uniques = pd.read_csv('dataset_only_uniques_renamed.csv')
df_nonoise = pd.read_csv('dataset_without_noise_renamed.csv')
df_foranalysis = pd.read_csv('final_dataset_for_analysis.csv')
# Out:
# /usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (12,19) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
total = 301766

# %%
def analyze(cols, df):
    res_12 = df.groupby(cols)
    res_12_unique = res_12.nunique()
    print(len(res_12_unique)-total)
    results_12 = res_12_unique[res_12_unique['SYNTHETIC_SSN']!=1]
    print(len(results_12))
    print(results_12.head())

# %% [markdown]
# # Acumen (Private Contractor) Analysis

# %%
df_acumenfull = pd.read_csv('./acumen_results/Acumen_dataset_for_analysis_ssnFull.csv')
df_acumen4 = pd.read_csv('./acumen_results/Acumen_dataset_for_analysis_ssn4.csv')

# %%
df_acumenfull.head()
# Out:
#    BID                          BID_HASH  ID SEX FIRSTNAME MIDDLENAME  \
# 0    0  CEC400AD0A71F79C1660A22771A10CE6   0   F   HARRIET        NaN
# 1    2  51E4D7678EB1DA790806E77DD6162FF4   2   M      PHIL        NaN
# 2    5  1E8ABAD9A8EBB18CFF1EDD6EA01ABB53   5   M    ROBERT          R
# 3   19  438D33CD47C0D0265163910631EA1F62  19   M         M          C
# 4   25  AE28FC5D0E13AF28018D64C30D07FED2  25   M    LOWELL          A
#
#    LASTNAME          COB  DOB  MOB   YOB CNOB  SUBJECTHASMIDDLENAME  \
# 0    TIEBEL  Grasonville   16    8  1985   US                 False
# 1     WELSH       Clever   28   12  1974   US                 False
# 2   RAFAJKO         Iuka    4   11  1958   US                  True
# 3  BARTLETT      Milmine   30    1  1966   US                  True
# 4   GLASGOW     Richford    9   10  1991   US                  True
#
#   SYNTHETIC_SSN                          SEX_HASH  \
# 0   535-58-4500  800618943025315F869E4E1F09471012
# ...

# %%
df_acumen4.head()
# Out:
#    BID                          BID_HASH  ID SEX FIRSTNAME MIDDLENAME  \
# 0    0  CEC400AD0A71F79C1660A22771A10CE6   0   F   HARRIET        NaN
# 1    2  51E4D7678EB1DA790806E77DD6162FF4   2   M      PHIL        NaN
# 2    5  1E8ABAD9A8EBB18CFF1EDD6EA01ABB53   5   M    ROBERT          R
# 3   19  438D33CD47C0D0265163910631EA1F62  19   M         M          C
# 4   25  AE28FC5D0E13AF28018D64C30D07FED2  25   M    LOWELL          A
#
#    LASTNAME          COB  DOB  MOB   YOB CNOB  SUBJECTHASMIDDLENAME  \
# 0    TIEBEL  Grasonville   16    8  1985   US                 False
# 1     WELSH       Clever   28   12  1974   US                 False
# 2   RAFAJKO         Iuka    4   11  1958   US                  True
# 3  BARTLETT      Milmine   30    1  1966   US                  True
# 4   GLASGOW     Richford    9   10  1991   US                  True
#
#   SYNTHETIC_SSN  SSN4                          SEX_HASH  \
# 0   535-58-4500  4500  800618943025315F869E4E1F09471012
# ...

# %% [raw]
# # uniques = 0
# for ind, row in df_uniques.iterrows():
#     matches = df_acumenfull[df_acumenfull['SYNTHETIC_SSN']==row['SYNTHETIC_SSN']]
#     uniques += matches[['BID']].nunique()-1
#     #print(matches[['BID', 'SYNTHETIC_SSN']])
#     #print('__________________')

# %%
analyze(['SYNTHETIC_SSN','BID_HASH'], df_acumenfull)
# Out:
# 0
# 0
# Empty DataFrame
# Columns: [BID, BID_HASH, ID, SEX, FIRSTNAME, MIDDLENAME, LASTNAME, COB, DOB, MOB, YOB, CNOB, SUBJECTHASMIDDLENAME, SYNTHETIC_SSN, SEX_HASH, FIRSTNAME_HASH, MIDDLENAME_HASH, LASTNAME_HASH, COB_HASH, DOB_HASH, MOB_HASH, YOB_HASH, CNOB_HASH, SUBJECTHASMIDDLENAME_HASH, SYNTHETIC_SSN_HASH]
# Index: []

# %%
df_acumenfull[df_acumenfull['BID_HASH']=='ACEE2A5F4E4DA7BF06563DB26502BA70']
# Out:
#             BID                          BID_HASH       ID SEX FIRSTNAME  \
# 864027  1345656  ACEE2A5F4E4DA7BF06563DB26502BA70  1345056   M      NARC
# 864028  1345656  ACEE2A5F4E4DA7BF06563DB26502BA70  1345356   M      MARC
# 864029  1345656  ACEE2A5F4E4DA7BF06563DB26502BA70  1345656   M      MARC
#
#        MIDDLENAME   LASTNAME     COB  DOB  MOB   YOB CNOB  \
# 864027          D  BENEVIDES  Morven    4    5  2000   US
# 864028          D  BRNEVIDES  Morven    4    5  2000   US
# 864029          D  BENEVIDES  Morven    4    5  2000   US
#
#         SUBJECTHASMIDDLENAME SYNTHETIC_SSN                          SEX_HASH  \
# 864027                  True   000-00-0220  69691C7BDCC3CE6D5D8A1361F22D04AC
# 864028                  True   000-00-0220  69691C7BDCC3CE6D5D8A1361F22D04AC
# 864029                  True   000-00-0220  69691C7BDCC3CE6D5D8A1361F22D04AC
#
#                           FIRSTNAME_HASH                   MIDDLENAME_HASH  \
# ...

# %%
df_acumenfull[df_acumenfull['BID_HASH']=='AD251A2FA21897BDB21EAB5BE22FF568']
# Out:
#              BID                          BID_HASH       ID SEX FIRSTNAME  \
# 2064300  2064312  AD251A2FA21897BDB21EAB5BE22FF568  1699568   F   MELISSA
# 2064301  2064312  AD251A2FA21897BDB21EAB5BE22FF568  1765798   F   MELISSA
# 2064302  2064312  AD251A2FA21897BDB21EAB5BE22FF568  1830462   F   MELISSA
# 2064303  2064312  AD251A2FA21897BDB21EAB5BE22FF568  1849902   F   MELISSA
# 2064304  2064312  AD251A2FA21897BDB21EAB5BE22FF568  1849923   F   MELISSA
# 2064305  2064312  AD251A2FA21897BDB21EAB5BE22FF568  1918420   F   MELISSA
# 2064306  2064312  AD251A2FA21897BDB21EAB5BE22FF568  1918510   F   MELISSA
# 2064307  2064312  AD251A2FA21897BDB21EAB5BE22FF568  1923228   F   MELISSA
# 2064308  2064312  AD251A2FA21897BDB21EAB5BE22FF568  1923281   F   MELISSA
# 2064309  2064312  AD251A2FA21897BDB21EAB5BE22FF568  2012782   M   MELISSA
# 2064310  2064312  AD251A2FA21897BDB21EAB5BE22FF568  2055828   F   JELISSA
# 2064311  2064312  AD251A2FA21897BDB21EAB5BE22FF568  2056166   F   MELISSA
# ...

# %%
res_12 = df_acumen4.groupby(['SSN4_HASH','BID_HASH'])
res_12_unique = res_12.nunique()
#print(len(res_12_unique)-total)
results_12 = res_12_unique[res_12_unique['SYNTHETIC_SSN']!=1]
print(len(results_12))
results_12
# Out:
# 11075
#                                                                    BID  \
# SSN4_HASH                        BID_HASH
# 002BDE245B08CF0D39EEA506F79C068B 120E7F78D63557DCB0BDBD7A421506FB    1
#                                  250E446B812FB08D4E4D057719EAC564    1
#                                  2E02C9E1D7C59D6A6D8B32776E954A6E    1
#                                  5374C264EF34955D45611FE719033F60    1
#                                  6BCD924ED1505981E06C132AC97645C0    1
# ...                                                                ...
# FFCC0D597D73D710C35AB1499ABB5783 8B0EF2B18B601974FCE36C221DB6E26D    1
#                                  8BA35F1F65C07B565666039AAC9621B4    1
#                                  C5C83AE5B4960B920798A0CFBB0DB48C    1
#                                  CAE2ED04EC632148082E2EAF09C6B3D6    1
#                                  F1B38F35CC2089696A7D515557AEB532    1
#
# ...

# %%
ssn4 = []
for ind, row in df_uniques.iterrows():
    last4 = row['SYNTHETIC_SSN'].split('-')[2]
    ssn4.append(last4)

# %%
from collections import Counter
a = dict(Counter(ssn4))
len(a)
# Out:
# 1000

# %%
res_3 = df_acumenfull.groupby(['SYNTHETIC_SSN_HASH','FIRSTNAME_HASH']).nunique()

# %%
len(res_3)-total
# Out:
# 79956

# %%
analyze(['SYNTHETIC_SSN_HASH','FIRSTNAME_HASH'], df_acumenfull)
# Out:
# 79956
# 0
# Empty DataFrame
# Columns: [BID, BID_HASH, ID, SEX, FIRSTNAME, MIDDLENAME, LASTNAME, COB, DOB, MOB, YOB, CNOB, SUBJECTHASMIDDLENAME, SYNTHETIC_SSN, SEX_HASH, FIRSTNAME_HASH, MIDDLENAME_HASH, LASTNAME_HASH, COB_HASH, DOB_HASH, MOB_HASH, YOB_HASH, CNOB_HASH, SUBJECTHASMIDDLENAME_HASH, SYNTHETIC_SSN_HASH]
# Index: []

# %%
res_4 = df_acumenfull.groupby(['SYNTHETIC_SSN_HASH','MOB_HASH','DOB_HASH','YOB_HASH']).nunique()

# %%
len(res_4)-total
# Out:
# 176150

# %%
analyze(['SYNTHETIC_SSN_HASH','MOB_HASH','DOB_HASH','YOB_HASH'], df_acumenfull)
# Out:
# 176150
# 0
# Empty DataFrame
# Columns: [BID, BID_HASH, ID, SEX, FIRSTNAME, MIDDLENAME, LASTNAME, COB, DOB, MOB, YOB, CNOB, SUBJECTHASMIDDLENAME, SYNTHETIC_SSN, SEX_HASH, FIRSTNAME_HASH, MIDDLENAME_HASH, LASTNAME_HASH, COB_HASH, DOB_HASH, MOB_HASH, YOB_HASH, CNOB_HASH, SUBJECTHASMIDDLENAME_HASH, SYNTHETIC_SSN_HASH]
# Index: []

# %%
res_5 = df_acumenfull.groupby(['SYNTHETIC_SSN_HASH','MOB_HASH','DOB_HASH','YOB_HASH','SEX_HASH']).nunique()
len(res_5)-total
# Out:
# 235998

# %%
analyze(['SYNTHETIC_SSN_HASH','MOB_HASH','DOB_HASH','YOB_HASH','SEX_HASH'], df_acumenfull)
# Out:
# 235998
# 0
# Empty DataFrame
# Columns: [BID, BID_HASH, ID, SEX, FIRSTNAME, MIDDLENAME, LASTNAME, COB, DOB, MOB, YOB, CNOB, SUBJECTHASMIDDLENAME, SYNTHETIC_SSN, SEX_HASH, FIRSTNAME_HASH, MIDDLENAME_HASH, LASTNAME_HASH, COB_HASH, DOB_HASH, MOB_HASH, YOB_HASH, CNOB_HASH, SUBJECTHASMIDDLENAME_HASH, SYNTHETIC_SSN_HASH]
# Index: []

# %%
a = ['00001861E70A70CF7020BFACBD295C41','3F9CA6D64C6EB9BF38962E0F6F04BA6B','31BA985D8385CC9F1DF47007E1404BFB','2E17CD1F06EC8063D4C5980A94C0A6CD','69691C7BDCC3CE6D5D8A1361F22D04AC']
df_acumenfull[(df_acumenfull['SYNTHETIC_SSN_HASH']==a[0]) & (df_acumenfull['MOB_HASH']==a[1])]
# Out:
#            BID                          BID_HASH      ID SEX FIRSTNAME  \
# 226848  435883  57030A4EF339238485935B38C174FF57  435883   M      KNUD
#
#        MIDDLENAME   LASTNAME    COB  DOB  MOB   YOB CNOB  \
# 226848        NaN  KRAGBALLE  Kinta    7    6  1975   US
#
#         SUBJECTHASMIDDLENAME SYNTHETIC_SSN                          SEX_HASH  \
# 226848                 False   917-79-4210  69691C7BDCC3CE6D5D8A1361F22D04AC
#
#                           FIRSTNAME_HASH                   MIDDLENAME_HASH  \
# 226848  E852A34EF964139712B99BB1B5AC6909  1545E945D5C3E7D9FA642D0A57FC8432
#
#                            LASTNAME_HASH                          COB_HASH  \
# 226848  CA7D93E0D8E60B8B940E3DF66EA89DE9  C63D6386A1DE8FD6A9DBB6BE9DE3F30D
#
#                                 DOB_HASH                          MOB_HASH  \
# 226848  31BA985D8385CC9F1DF47007E1404BFB  3F9CA6D64C6EB9BF38962E0F6F04BA6B
#
#                                 YOB_HASH                         CNOB_HASH  \
# ...

# %% [raw]
# res_12 = df_acumenfull.groupby(['FIRSTNAME_HASH','LASTNAME_HASH','MOB_HASH','DOB_HASH','YOB_HASH'])
# res_12_unique = res_12.nunique()
# print(len(res_12_unique)-total)
# results_12 = res_12_unique[res_12_unique['SYNTHETIC_SSN']!=1]
# print(len(results_12))
# results_12

# %%
analyze(['LASTNAME_HASH','FIRSTNAME_HASH','DOB_HASH'], df_acumenfull)
# Out:
# 91418
# 6898
#                                                                                                     BID  \
# LASTNAME_HASH                    FIRSTNAME_HASH                   DOB_HASH
# 000440106FE11615ED6F4C8600743058 C7C1A2A1BE57AAC298DE6994BBB40E3A DB00977F60FF83DFA7706918CDBC2F4F    2
# 00050C6575F12CE948A53BD73E744310 0DDD386C1680B372561068DD81B593AA 6E41387043E264632B5326FFC4AF1DA0    2
# 0011CBC1CCC1518E411FC12D2F3592AB E6A9550DA67DA54CFC60C40F5DCAE3C3 AB4F28370A881060BAAC580308242BB0    2
# 0027C9741AEF6D41D30BC53F87C7E7F0 037D4DB2CE511A31A3FB5E4BC07A10A7 0833316314B11980860455E8A19C6B1D    2
# 0038BC8349B15BA7BA3B91B2C4426BCA 6A697EDFC8461B58F10D5CE6E3B6705B 2F337B9E29CB0373613942EDDD2B11AE    2
#
#                                                                                                     BID_HASH  \
# LASTNAME_HASH                    FIRSTNAME_HASH                   DOB_HASH
# ...

# %%
#df_acumenfull[df_acumenfull.duplicated(subset=['FIRSTNAME_HASH','LASTNAME_HASH','MOB_HASH','DOB_HASH','YOB_HASH'], keep=False)]

# %%
analyze(['SSN4_HASH','FIRSTNAME_HASH','LASTNAME_HASH','YOB_HASH'], df_acumen4)
# Out:
# 267264
# 15
#                                                                                                                                      BID  \
# SSN4_HASH                        FIRSTNAME_HASH                   LASTNAME_HASH                    YOB_HASH
# 4353C108EC0FFF45C1F6E6C899D53B0E 3FABF3BED61F09466AD81C815289B2D2 E25670A249766F3FFE0E3CA9ECF2DB79 6FEBF89892ADD388AF08B6D91E5C3B01    1
# 4844A582858FDDCC158D446B116DC34A 9D116ECF9009202ECDEAB8C3BB6A4F97 4B7FE34E2800D468AA24A17E82BFD229 97E06C04CAF58095247C6A1BE9E47D11    1
# 4AB11B0B69585D82CD17BB68B04B62A7 1260D173FA45D25E905087BA79187B3F D13503BF7A87609B17FF815190CED579 2AEE5AE0557E77A81669595D2C002BFB    1
# 57AFFC98BD860CB5AFE6F708FC13F9B2 B6AB2E0560DBC1430BECC9E8DF975551 B5C68C2D2FC95B040914012D76AEA686 B5477D5A88AEE4A606F893548A567B1E    1
# 5E34DD65B4650D908E865CA39CB70F1C 20FD3AE5ED6CB8E993ECADB203FE1BBE F5070750873D4CD6194D0E89F92ACF03 97E06C04CAF58095247C6A1BE9E47D11    1
#
# ...

# %%
df_tmp = df_acumen4
df_tmp.drop_duplicates(['SSN4'])
# Out:
#         BID                          BID_HASH     ID SEX FIRSTNAME MIDDLENAME  \
# 0         0  CEC400AD0A71F79C1660A22771A10CE6      0   F   HARRIET        NaN
# 1         2  51E4D7678EB1DA790806E77DD6162FF4      2   M      PHIL        NaN
# 2         5  1E8ABAD9A8EBB18CFF1EDD6EA01ABB53      5   M    ROBERT          R
# 3        19  438D33CD47C0D0265163910631EA1F62     19   M         M          C
# 4        25  AE28FC5D0E13AF28018D64C30D07FED2     25   M    LOWELL          A
# ...     ...                               ...    ...  ..       ...        ...
# 7103  33000  4826AF433CDE95BF14879A22FF2E7AEC  33000   M    ARNOLD       ST J
# 7363  35035  42946A47D75E72C59F201BC1BA3F2451  14422   M     CYRIL          S
# 7726  38125  BEE428C4E4A9B6967DF6700D65CCCB2C  38125   F         R       KENT
# 7808  38626  1AAA1573677FA4E74DDDA5F6FCCFF11C  38626   F    KAYMAN          E
# 7997  39898  C6EF343A23A8F5EBB2D58C1A71BDA725  39898   M    KRISNA        NaN
#
# ...

# %% [markdown]
# # SHA-512 Hashing Algorithm Analysis

# %%
import hashlib
df_foranalysis = pd.read_csv('final_dataset_for_analysis.csv')

# %%
def hash(sourcedf,destinationdf,*column):
    columnName = 'hash_'
    for i in column:
        columnName = columnName + i
    hashColumn = pd.Series()
    for i in range((len(sourcedf[column[0]]))):
        concatstr = ''
        for j in column:
            concatstr = concatstr + sourcedf[j][i]
        hashColumn.at[i] = hashlib.sha512( concatstr.encode("utf-8") ).hexdigest()
    destinationdf[columnName] = hashColumn

def hash2(sourcedf,destinationdf,*column):
    columnName = ''
    destinationdf['hash_'+columnName.join(column)] = pd.DataFrame(sourcedf[list(column)].values.sum(axis=1))[0].str.encode('utf-8').apply(lambda x: (hashlib.sha512(x).hexdigest().upper()))

# %%
df_customfull = pd.DataFrame()
df_customfull = df_foranalysis

# %%
newlasts = ['']*len(df_foranalysis)
i = 0
for ind, row in df_foranalysis.iterrows():
    newlasts[i] = str(row['LASTNAME']).replace(' ','')
    i += 1

# %%
df_foranalysis['LASTNAME'] = newlasts

# %%
ssn4 = ['']*len(df_foranalysis)
i = 0
for ind, row in df_foranalysis.iterrows():
    last4 = row['SYNTHETIC_SSN'].split('-')[2]
    ssn4[i] = last4
    i += 1

# %%
df_foranalysis['SSN4'] = ssn4

# %%
df_foranalysis = df_foranalysis.astype(str)
df_foranalysis.head(5)
# Out:
#   Unnamed: 0 Unnamed: 0.1   ID SEX FIRSTNAME MIDDLENAME   LASTNAME  \
# 0          0            0  0.0   F   HARRIET        nan     TIEBEL
# 1          1            1  1.0   M    GERALD        nan  ELLINGSON
# 2          2            2  2.0   M      PHIL        nan      WELSH
# 3          3            3  3.0   M   RAYMOND          H    GIESLER
# 4          4            4  4.0   M      JOHN          S   THOMPSON
#
#             COB   DOB   MOB     YOB CNOB SUBJECTHASMIDDLENAME SYNTHETIC_SSN  \
# 0   Grasonville  16.0   8.0  1985.0   US                False   535-58-4500
# 1        Wausau  24.0  12.0  1964.0   US                False   014-49-9410
# 2        Clever  28.0  12.0  1974.0   US                False   450-19-0450
# 3  Clintonville  27.0  12.0  1973.0   US                 True   310-20-1010
# 4     Lohrville   4.0   5.0  1988.0   US                 True   956-64-3720
#
#    SSN4
# 0  4500
# 1  9410
# 2  0450
# 3  1010
# 4  3720

# %%
cols =['SEX','FIRSTNAME','LASTNAME','COB','DOB','MOB','YOB','CNOB','SUBJECTHASMIDDLENAME','SYNTHETIC_SSN', 'SSN4']
for col in cols:
    hash2(df_foranalysis, df_customfull, col)
    print('FINISHED '+str(col))
# Out:
# FINISHED SEX
# FINISHED FIRSTNAME
# FINISHED LASTNAME
# FINISHED COB
# FINISHED DOB
# FINISHED MOB
# FINISHED YOB
# FINISHED CNOB
# FINISHED SUBJECTHASMIDDLENAME
# FINISHED SYNTHETIC_SSN
# FINISHED SSN4

# %%
df_customfull.to_csv('custom_hashed_datasetfull.csv')
df_customfull
# Out:
#          Unnamed: 0  Unnamed: 0.1         ID SEX FIRSTNAME MIDDLENAME  \
# 0                 0             0        0.0   F   HARRIET        NaN
# 1                 1             1        1.0   M    GERALD        NaN
# 2                 2             2        2.0   M      PHIL        NaN
# 3                 3             3        3.0   M   RAYMOND          H
# 4                 4             4        4.0   M      JOHN          S
# ...             ...           ...        ...  ..       ...        ...
# 2064308     2064308       2064308  2064308.0   M       UWE        NaN
# 2064309     2064309       2064309  2064309.0   F   SUZANNE        NaN
# 2064310     2064310       2064310  2064310.0   M    JOSEPH        NaN
# 2064311     2064311       2064311  2064311.0   M       ABE        NaN
# 2064312     2064312       2064312  2064312.0   F   MELISSA         E.
#
#            LASTNAME              COB   DOB   MOB     YOB CNOB  \
# 0            TIEBEL      Grasonville  16.0   8.0  1985.0   US
# ...

# %%
tmp = df_withencoding[['ZIP_CODE','SYNTHETIC_SSN']]
tmp
# Out:
#          ZIP_CODE SYNTHETIC_SSN
# 0         21638.0   535-58-4500
# 1         32463.0   014-49-9410
# 2         65631.0   450-19-0450
# 3         16372.0   310-20-1010
# 4         51453.0   956-64-3720
# ...           ...           ...
# 2064308   54513.0   508-09-8480
# 2064309   89820.0   762-06-9120
# 2064310   20622.0   518-42-6670
# 2064311    7718.0   569-99-5710
# 2064312   28324.0   632-72-3830
#
# [2064313 rows x 2 columns]

# %%
df_customfull['ZIPCODE'] = tmp['ZIP_CODE']

# %%
df_customfull = df_customfull.astype(str)
df_customfull.head(5)
# Out:
#   Unnamed: 0 Unnamed: 0.1   ID SEX FIRSTNAME MIDDLENAME   LASTNAME  \
# 0          0            0  0.0   F   HARRIET        nan     TIEBEL
# 1          1            1  1.0   M    GERALD        nan  ELLINGSON
# 2          2            2  2.0   M      PHIL        nan      WELSH
# 3          3            3  3.0   M   RAYMOND          H    GIESLER
# 4          4            4  4.0   M      JOHN          S   THOMPSON
#
#             COB   DOB   MOB     YOB CNOB SUBJECTHASMIDDLENAME SYNTHETIC_SSN  \
# 0   Grasonville  16.0   8.0  1985.0   US                False   535-58-4500
# 1        Wausau  24.0  12.0  1964.0   US                False   014-49-9410
# 2        Clever  28.0  12.0  1974.0   US                False   450-19-0450
# 3  Clintonville  27.0  12.0  1973.0   US                 True   310-20-1010
# 4     Lohrville   4.0   5.0  1988.0   US                 True   956-64-3720
#
#                                             hash_SEX  \
# ...

# %%
hash2(df_customfull, df_customfull, 'ZIPCODE')

# %%
analyze(['hash_LASTNAME','hash_FIRSTNAME', 'hash_DOB'], df_customfull)
# Out:
# 91415
# 6920
#                                                                                                                                                           Unnamed: 0  \
# hash_LASTNAME                                      hash_FIRSTNAME                                     hash_DOB
# 0002E1E573537270266D043431E7594D80743EEED523E57... 0D8355391F5CE198B49546806B7B786A7D0128C80C297DA... 62B4DA4ABC10466431DDC1B0D91AAEB4F4D7EC4A28EE892...           3
#                                                    28FC0F80A8622524EDCBBBF7AF522F59D6DCD28935886D3... 5045CD4A4785DC01DE56EA2EE52CF746CB05F7F45E41E6C...           9
#                                                    7DBAD08EFC7D3D11AD8BF2A9A8DC808DDD716AA9A263B3A... 3CD487C1435418382C2BE5E707F76F16C38F2D643FF75DE...           7
#                                                    95C6D09529ABF79F1514FD469E9840C2F8EC3485C93CBF4... F836D4A58C8A673C7861C98C1B2C965ABA962FF5DBD77B8...          31
# ...

# %%
init1 = ['']*len(df_customfull)
init3 = ['']*len(df_customfull)
i = 0
for ind, row in df_customfull.iterrows():
    first1 = row['FIRSTNAME'][0:min(len(row['FIRSTNAME']), 1)]
    first3 = row['FIRSTNAME'][0:min(len(row['FIRSTNAME']), 3)]
    init1[i] = first1
    init3[i] = first3
    i += 1

# %%
print(init1[0:5])
print(init3[0:5])
print(df_customfull['FIRSTNAME'].head())
# Out:
# ['H', 'G', 'P', 'R', 'J']
# ['HAR', 'GER', 'PHI', 'RAY', 'JOH']
# 0    HARRIET
# 1     GERALD
# 2       PHIL
# 3    RAYMOND
# 4       JOHN
# Name: FIRSTNAME, dtype: object

# %%
df_customfull['FIRSTNAME1'] = init1
df_customfull['FIRSTNAME3'] = init3
df_customfull.head()
# Out:
#   Unnamed: 0 Unnamed: 0.1   ID SEX FIRSTNAME MIDDLENAME   LASTNAME  \
# 0          0            0  0.0   F   HARRIET        nan     TIEBEL
# 1          1            1  1.0   M    GERALD        nan  ELLINGSON
# 2          2            2  2.0   M      PHIL        nan      WELSH
# 3          3            3  3.0   M   RAYMOND          H    GIESLER
# 4          4            4  4.0   M      JOHN          S   THOMPSON
#
#             COB   DOB   MOB     YOB CNOB SUBJECTHASMIDDLENAME SYNTHETIC_SSN  \
# 0   Grasonville  16.0   8.0  1985.0   US                False   535-58-4500
# 1        Wausau  24.0  12.0  1964.0   US                False   014-49-9410
# 2        Clever  28.0  12.0  1974.0   US                False   450-19-0450
# 3  Clintonville  27.0  12.0  1973.0   US                 True   310-20-1010
# 4     Lohrville   4.0   5.0  1988.0   US                 True   956-64-3720
#
#                                             hash_SEX  \
# ...

# %%
df_customfull = df_customfull.astype(str)

# %%
hash2(df_customfull, df_customfull, 'FIRSTNAME1')
hash2(df_customfull, df_customfull, 'FIRSTNAME3')

# %%
analyze(['hash_LASTNAME','hash_FIRSTNAME', 'hash_SEX','hash_DOB','hash_YOB','hash_MOB'], df_customfull)
# Out:
# 325366
# 44
#                                                                                                                                                                                                                                                                                                                    Unnamed: 0  \
# hash_LASTNAME                                      hash_FIRSTNAME                                     hash_SEX                                           hash_DOB                                           hash_YOB                                           hash_MOB
# 0080CE0B8A317E71796ABA3FDCA2863D1682413C46897C8... BB233831B2E9ECCF139B12DC09566F2A90C08F7A93B3C98... 253405E03B91441A6DD354A9B72E040068B1BFE10E83EB1... A22C5CF81950F29428033F6D91A6A5EE9E1309370942168... 0E43380EB818634C7B0F9614DF2AD9E6D05F62072575C8E... 4677C67E1DAD1CF9E88E26832D1B379F7748E91F580D832...           4
# ...

# %%
analyze(['hash_LASTNAME','hash_FIRSTNAME3', 'hash_SEX','hash_DOB','hash_YOB','hash_MOB'], df_customfull)
# Out:
# 325363
# 47
#                                                                                                                                                                                                                                                                                                                    Unnamed: 0  \
# hash_LASTNAME                                      hash_FIRSTNAME3                                    hash_SEX                                           hash_DOB                                           hash_YOB                                           hash_MOB
# 0080CE0B8A317E71796ABA3FDCA2863D1682413C46897C8... 1A0725FE28E30DED58B78CFF0BB26A005E29A30646FB9A7... 253405E03B91441A6DD354A9B72E040068B1BFE10E83EB1... A22C5CF81950F29428033F6D91A6A5EE9E1309370942168... 0E43380EB818634C7B0F9614DF2AD9E6D05F62072575C8E... 4677C67E1DAD1CF9E88E26832D1B379F7748E91F580D832...           4
# ...

# %%
analyze(['hash_LASTNAME','hash_FIRSTNAME','hash_DOB','hash_YOB','hash_MOB'], df_customfull)
# Out:
# 267248
# 46
#                                                                                                                                                                                                                                                                 Unnamed: 0  \
# hash_LASTNAME                                      hash_FIRSTNAME                                     hash_DOB                                           hash_YOB                                           hash_MOB
# 0080CE0B8A317E71796ABA3FDCA2863D1682413C46897C8... BB233831B2E9ECCF139B12DC09566F2A90C08F7A93B3C98... A22C5CF81950F29428033F6D91A6A5EE9E1309370942168... 0E43380EB818634C7B0F9614DF2AD9E6D05F62072575C8E... 4677C67E1DAD1CF9E88E26832D1B379F7748E91F580D832...           4
# ...

# %% [markdown]
# # Datavant Token Analysis

# %%
datavant0 = pd.read_csv('./datavant_results/nia_part_0')
datavant1 = pd.read_csv('./datavant_results/nia_part_1')
datavant2 = pd.read_csv('./datavant_results/nia_part_2')
datavant3 = pd.read_csv('./datavant_results/nia_part_3')
datavant4 = pd.read_csv('./datavant_results/nia_part_4')
datavant_dfs = [datavant0, datavant1, datavant2, datavant3, datavant4]
df_datavant = pd.concat(datavant_dfs)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-355-53aed00c89e9> in <module>
#       1 datavant0 = pd.read_csv('./datavant_results/nia_part_0')
# ----> 2 datavant1 = pd.read_csv('./datavant_results/nia_part_1')
#       3 datavant2 = pd.read_csv('./datavant_results/nia_part_2')
#       4 datavant3 = pd.read_csv('./datavant_results/nia_part_3')
#       5 datavant4 = pd.read_csv('./datavant_results/nia_part_4')
#
# ...

# %%
df_datavant.head()
# Out:
#       ID SEX FIRSTNAME MIDDLENAME     LASTNAME             COB         DOB  \
# 0  144.0   M  BENJAMIN          W  PAPERMASTER      Vanderbilt  03/09/1979
# 1   97.0   M      JOHN          E        VERNA         Shubuta  11/17/1983
# 2   22.0   M   JEFFREY          C     DUENWALD          Olalla  06/18/1952
# 3   54.0   F      PAUL          A       CANTOR         Saginaw  10/21/1971
# 4  117.0   M   CLEMENT          C       DARROW  Taylors Island  09/20/1971
#
#   CNOB SUBJECTHASMIDDLENAME SYNTHETIC_SSN  \
# 0   US                 True   011-66-6200
# 1   US                 True   103-63-1880
# 2   US                 True   557-02-3260
# 3   US                 True   396-41-0550
# 4   US                 True   798-98-5180
#
#                                         token_1  \
# 0  xSCCi7Bkq3VVzttFtTU4cdL+q/zSkLZq0pQfI/tCtwM=
# 1  L8apzXxNUi29JijbJnJg0AfVD8A8o5/yK8TS65fhgvg=
# 2  J+kC0KKl4dcUyK1E/esuCjmnP+uhmU8klTdBjWYbVpI=
# 3  qpHw9GsvmVuMDasYN6WbwG9cZBusczT2usTF2mnZz9U=
# ...

# %%
analyze(['token_38'], df_datavant)
# Out:
# 246823
# 49
#                                               ID  SEX  FIRSTNAME  MIDDLENAME  \
# token_38
# +rysDKXorH2VaW6VKLR1qAo+20XEDu1VpPIqJR48EU0=  23    1          1           1
# 0Y8KniRT2DOC9l6j/8e6PAy97bjcjFKoyiM3xweLJ4E=   4    1          1           1
# 3rOsxUJVttNcnImxT8xyyUIynB19WL5imWvOdovaT5U=   7    1          1           2
# 8+Qbp0x9BAwbExNLBCbJxej4mU3PwJ96GOyYaNbjqZw=  53    2          1           2
# 85IfZNBQlLhrFl9pDNZAUT+AAwhdZdMpI71hKYTJiNI=   3    1          1           1
#
#                                               LASTNAME  COB  DOB  CNOB  \
# token_38
# +rysDKXorH2VaW6VKLR1qAo+20XEDu1VpPIqJR48EU0=         1    2    1     1
# 0Y8KniRT2DOC9l6j/8e6PAy97bjcjFKoyiM3xweLJ4E=         1    2    1     1
# 3rOsxUJVttNcnImxT8xyyUIynB19WL5imWvOdovaT5U=         1    2    1     1
# 8+Qbp0x9BAwbExNLBCbJxej4mU3PwJ96GOyYaNbjqZw=         1    1    1     1
# 85IfZNBQlLhrFl9pDNZAUT+AAwhdZdMpI71hKYTJiNI=         1    2    1     1
#
# ...
