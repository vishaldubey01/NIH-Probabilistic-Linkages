# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('to_analyze.csv')

# %%
df.head()
# Out:
#    Unnamed: 0           GRANT_NUM  SUBJECTHASMIDDLENAME      FY        GIID  \
# 0           0  1N01AH004000-00070                 False  1970.0  535-58-450
# 1           1  1N01AH004103-00070                 False  1970.0  014-49-941
# 2           2  1N01AH004172-00070                 False  1970.0  450-19-045
# 3           3  1N01AH004196-00070                  True  1970.0  310-20-101
# 4           4  1N01AI002011-00070                  True  1970.0  956-64-372
#
#             COB PI_LAST_NAME     YOB  INDEX SEX GRANT_NUM_STEM  \
# 0   Grasonville       TIEBEL  1985.0    0.0   F   1N01AH004000
# 1        Wausau    ELLINGSON  1964.0    1.0   M   1N01AH004103
# 2        Clever        WELSH  1974.0    2.0   M   1N01AH004172
# 3  Clintonville      GIESLER  1973.0    3.0   M   1N01AH004196
# 4     Lohrville     THOMPSON  1988.0    4.0   M   1N01AI002011
#
#                                    ORG_NAME  ZIP_CODE   MOB PI_FIRST_NAME  \
# ...

# %%
df.rename(columns={'GIID': 'SYNTHETIC_SSN','PI_FIRST_NAME': 'FIRSTNAME', 'PI_MIDDLE_NAME':'MIDDLENAME', 'PI_LAST_NAME':'LASTNAME', 'INDEX':'ID' }, inplace=True)

# %%
df
# Out:
#          Unnamed: 0           GRANT_NUM  SUBJECTHASMIDDLENAME      FY  \
# 0                 0  1N01AH004000-00070                 False  1970.0
# 1                 1  1N01AH004103-00070                 False  1970.0
# 2                 2  1N01AH004172-00070                 False  1970.0
# 3                 3  1N01AH004196-00070                  True  1970.0
# 4                 4  1N01AI002011-00070                  True  1970.0
# ...             ...                 ...                   ...     ...
# 2064308     2064308   N44CN000000-00409                 False  2009.0
# 2064309     2064309   N44CO000000-00009                 False  2009.0
# 2064310     2064310   N44DA000000-00409                 False  2009.0
# 2064311     2064311   N44HB000000-00009                 False  2009.0
# 2064312     2064312   N44MH000000-00509                  True  2009.0
#
#         SYNTHETIC_SSN              COB    LASTNAME     YOB         ID SEX  \
# ...

# %%
cols = ['ID','SEX','FIRSTNAME','MIDDLENAME','LASTNAME','COB','DOB','MOB','YOB','CNOB','SUBJECTHASMIDDLENAME','SYNTHETIC_SSN']
df = df[cols]

# %%
df.head()
# Out:
#     ID SEX FIRSTNAME MIDDLENAME   LASTNAME           COB   DOB   MOB     YOB  \
# 0  0.0   F   HARRIET        NaN     TIEBEL   Grasonville  16.0   8.0  1985.0
# 1  1.0   M    GERALD        NaN  ELLINGSON        Wausau  24.0  12.0  1964.0
# 2  2.0   M      PHIL        NaN      WELSH        Clever  28.0  12.0  1974.0
# 3  3.0   M   RAYMOND          H    GIESLER  Clintonville  27.0  12.0  1973.0
# 4  4.0   M      JOHN          S   THOMPSON     Lohrville   4.0   5.0  1988.0
#
#   CNOB  SUBJECTHASMIDDLENAME SYNTHETIC_SSN
# 0   US                 False    535-58-450
# 1   US                 False    014-49-941
# 2   US                 False    450-19-045
# 3   US                  True    310-20-101
# 4   US                  True    956-64-372

# %%
df.to_csv('final_dataset_for_analysis.csv')

# %%
df.shape
# Out:
# (2064313, 12)

# %%
uniques = pd.read_csv('dataset_only_uniques.csv')

# %%
uniques.rename(columns={'GIID': 'SYNTHETIC_SSN','PI_FIRST_NAME': 'FIRSTNAME', 'PI_MIDDLE_NAME':'MIDDLENAME', 'PI_LAST_NAME':'LASTNAME', 'INDEX':'ID' }, inplace=True)

# %%
uniques.to_csv('dataset_only_uniques_renamed.csv')

# %%
no_noise = pd.read_csv('dataset_without_noise.csv')
# Out:
# /usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (10,17) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
no_noise.rename(columns={'GIID': 'SYNTHETIC_SSN','PI_FIRST_NAME': 'FIRSTNAME', 'PI_MIDDLE_NAME':'MIDDLENAME', 'PI_LAST_NAME':'LASTNAME', 'INDEX':'ID' }, inplace=True)

# %%
no_noise.to_csv('dataset_without_noise_renamed.csv')

# %%
encoded = pd.read_csv('noisy_data_with_encodings.csv')

# %%
encoded.rename(columns={'GIID': 'SYNTHETIC_SSN','PI_FIRST_NAME': 'FIRSTNAME', 'PI_MIDDLE_NAME':'MIDDLENAME', 'PI_LAST_NAME':'LASTNAME', 'INDEX':'ID' }, inplace=True)

# %%
encoded.to_csv('dataset_noisy_with_encodings_renamed.csv')

# %%
df = pd.read_csv('final_dataset_for_analysis.csv')
df.head()
# Out:
#    Unnamed: 0   ID SEX FIRSTNAME MIDDLENAME   LASTNAME           COB   DOB  \
# 0           0  0.0   F   HARRIET        NaN     TIEBEL   Grasonville  16.0
# 1           1  1.0   M    GERALD        NaN  ELLINGSON        Wausau  24.0
# 2           2  2.0   M      PHIL        NaN      WELSH        Clever  28.0
# 3           3  3.0   M   RAYMOND          H    GIESLER  Clintonville  27.0
# 4           4  4.0   M      JOHN          S   THOMPSON     Lohrville   4.0
#
#     MOB     YOB CNOB  SUBJECTHASMIDDLENAME SYNTHETIC_SSN
# 0   8.0  1985.0   US                 False    535-58-450
# 1  12.0  1964.0   US                 False    014-49-941
# 2  12.0  1974.0   US                 False    450-19-045
# 3  12.0  1973.0   US                  True    310-20-101
# 4   5.0  1988.0   US                  True    956-64-372

# %%
newssns = ['0']*len(df['SYNTHETIC_SSN'])
i = 0
for ind, row in df.iterrows():
    #print(row['SYNTHETIC_SSN']+'0')
    #newssns.append(row['SYNTHETIC_SSN']+'0')
    newssns[i] = row['SYNTHETIC_SSN']+'0'
    i += 1

# %%
df['SYNTHETIC_SSN'] = newssns
#df['SYNTHETIC_SSN']

# %%
df.to_csv('final_dataset_for_analysis.csv')

# %%
uniques = pd.read_csv('dataset_only_uniques_renamed.csv')
uniques.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  ID  INDEX.1 SEX FIRSTNAME MIDDLENAME   LASTNAME  \
# 0           0             0   0        0   F   HARRIET        NaN     TIEBEL
# 1           1             1   1        1   M    GERALD        NaN  ELLINGSON
# 2           2             2   2        2   M      PHIL        NaN      WELSH
# 3           3             3   3        3   M   RAYMOND          H    GIESLER
# 4           4             4   4        4   M      JOHN          S   THOMPSON
#
#    DOB  MOB  ...  SYNTHETIC_SSN                                  ORG_NAME  \
# 0    3    7  ...     535-58-450        AMERICAN OCCUPATIONAL THERAPY ASSN
# 1    8    8  ...     014-49-941  U.S. DEPT OF HLTH & HUMAN SRVS-DUMMY REC
# 2    5    4  ...     450-19-045               COMPUTER APPLICATIONS, INC.
# 3   29    3  ...     310-20-101    HOSPITAL EDUCATIONAL AND RES FDN OF PA
# 4   16    3  ...     956-64-372                        UNIVERSITY OF IOWA
#
#      FY           GRANT_NUM GRANT_NUM_STEM  \
# ...

# %%
newssns = ['0']*len(uniques['SYNTHETIC_SSN'])
i = 0
for ind, row in uniques.iterrows():
    #print(row['SYNTHETIC_SSN']+'0')
    #newssns.append(row['SYNTHETIC_SSN']+'0')
    newssns[i] = row['SYNTHETIC_SSN']+'0'
    i += 1
uniques['SYNTHETIC_SSN'] = newssns
uniques.to_csv('dataset_only_uniques_renamed.csv')

# %%
no_noise = pd.read_csv('dataset_without_noise_renamed.csv')

newssns = ['0']*len(no_noise['SYNTHETIC_SSN'])
i = 0
for ind, row in no_noise.iterrows():
    #print(row['SYNTHETIC_SSN']+'0')
    #newssns.append(row['SYNTHETIC_SSN']+'0')
    newssns[i] = row['SYNTHETIC_SSN']+'0'
    i += 1
no_noise['SYNTHETIC_SSN'] = newssns
no_noise.to_csv('dataset_without_noise_renamed.csv')
no_noise.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  ID    FY  \
# 0           0             0               0   0  1970
# 1           1             1               1   1  1970
# 2           2             2               2   2  1970
# 3           3             3               3   3  1970
# 4           4             4               4   4  1970
#
#                                    ORG_NAME STATE_CODE  ZIP_CODE FIRSTNAME  \
# 0        AMERICAN OCCUPATIONAL THERAPY ASSN         MD     21638   HARRIET
# 1  U.S. DEPT OF HLTH & HUMAN SRVS-DUMMY REC         FL     32463    GERALD
# 2               COMPUTER APPLICATIONS, INC.         MO     65631      PHIL
# 3    HOSPITAL EDUCATIONAL AND RES FDN OF PA         PA     16372   RAYMOND
# 4                        UNIVERSITY OF IOWA         IA     51453      JOHN
#
#   MIDDLENAME  ... SYNTHETIC_SSN CHANGED_ZIP CHANGED_SEX CHANGED_YOB  \
# 0        NaN  ...   535-58-4500       False       False       False
# ...

# %%
encodings = pd.read_csv('dataset_noisy_with_encodings_renamed.csv')

newssns = ['0']*len(encodings['SYNTHETIC_SSN'])
i = 0
for ind, row in encodings.iterrows():
    #print(row['SYNTHETIC_SSN']+'0')
    #newssns.append(row['SYNTHETIC_SSN']+'0')
    newssns[i] = row['SYNTHETIC_SSN']+'0'
    i += 1
encodings['SYNTHETIC_SSN'] = newssns
encodings.to_csv('dataset_noisy_with_encodings_renamed.csv')
encodings.head()
# Out:
# /usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (11,18) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1   ID      FY  \
# 0           0             0             0.0  0.0  1970.0
# 1           1             1             1.0  1.0  1970.0
# 2           2             2             2.0  2.0  1970.0
# 3           3             3             3.0  3.0  1970.0
# 4           4             4             4.0  4.0  1970.0
#
#                                    ORG_NAME STATE_CODE  ZIP_CODE FIRSTNAME  \
# 0        AMERICAN OCCUPATIONAL THERAPY ASSN         MD   21638.0   HARRIET
# 1  U.S. DEPT OF HLTH & HUMAN SRVS-DUMMY REC         FL   32463.0    GERALD
# 2               COMPUTER APPLICATIONS, INC.         MO   65631.0      PHIL
# 3    HOSPITAL EDUCATIONAL AND RES FDN OF PA         PA   16372.0   RAYMOND
# ...
